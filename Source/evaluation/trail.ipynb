# %%
import os
from deepeval.test_case import LLMTestCase
from deepeval.tracing import observe, update_current_span
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

@observe(metric_collection="My Collection")
def llm_app(query: str) -> str:
    res = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "user", "content": query}
        ]
    ).choices[0].message.content

    update_current_span(test_case=LLMTestCase(input=query, actual_output=res))
    return res

llm_app("Write me a poem.")
# Out:
# "In the hush of dawn's embrace,  \nWhen the world stirs from its dreams,  \nA symphony of light and grace  \nDances on the silver streams.  \n\nWhispers of the morning breeze  \nSway the flowers in gentle rhyme,  \nLeaves sing softly in the trees,  \nMarking the fleeting trace of time.  \n\nGolden hues paint skies so wide,  \nA masterpiece of warmth and glow,  \nAs the sun begins its glide,  \nIgniting the earth below.  \n\nIn the quiet heart of morn,  \nHope awakens with the light,  \nNew beginnings softly born,  \nCasting shadows of the night.  \n\nNature speaks in silent ways,  \nStories of the world untold,  \nIn this tranquil dawn's embrace,  \nLife's mysteries unfold.  "

# %%
import os
os.chdir("C:/vscode/graph-rag/Source")

# %%
from main import evaluate
from config.settings_loader import load_config

config = load_config("config/config.yaml")

# %%
ground_truth_path = config["evaluation"]["ground_truth_path"]
ground_truth_path
# Out:
# 'evaluation\\ground_truth\\ground_truth.jsonl'

# %%
import pandas as pd

df = pd.read_csv(r"C:\vscode\graph-rag\Source\evaluation\results\evaluation_results.csv")

# %%
df.drop(columns=['actual_output', 'expected_output','retrieval_context'], inplace=True)

# %%
df
# Out:
#                                                 input                metric  \
# 0   What condition did the Roman Empire enjoy duri...  contextual_precision
# 1   What condition did the Roman Empire enjoy duri...     contextual_recall
# 2   What condition did the Roman Empire enjoy duri...  contextual_relevancy
# 3   What condition did the Roman Empire enjoy duri...      answer_relevancy
# 4   What condition did the Roman Empire enjoy duri...          faithfulness
# 5   Why did Augustus abandon further territorial e...  contextual_precision
# 6   Why did Augustus abandon further territorial e...     contextual_recall
# 7   Why did Augustus abandon further territorial e...  contextual_relevancy
# 8   Why did Augustus abandon further territorial e...      answer_relevancy
# 9   Why did Augustus abandon further territorial e...          faithfulness
# 10  How did Augustus recover Roman standards lost ...  contextual_precision
# 11  How did Augustus recover Roman standards lost ...     contextual_recall
# 12  How did Augustus recover Roman standards lost ...  contextual_relevancy
# 13  How did Augustus recover Roman standards lost ...      answer_relevancy
# 14  How did Augustus recover Roman standards lost ...          faithfulness
# 15   Why was Germany considered difficult to conquer?  contextual_precision
# 16   Why was Germany considered difficult to conquer?     contextual_recall
# 17   Why was Germany considered difficult to conquer?  contextual_relevancy
# 18   Why was Germany considered difficult to conquer?      answer_relevancy
# 19   Why was Germany considered difficult to conquer?          faithfulness
#
#        score                                             reason
# 0   0.581097  The score is 0.58 because while several releva...
# 1   1.000000  The score is 1.00 because all sentences in the...
# 2   0.544118  The score is 0.54 because, while there are sev...
# 3   1.000000  The score is 1.00 because the answer was fully...
# 4   1.000000  The score is 1.00 because there are no contrad...
# 5   0.666667  The score is 0.67 because the first node in th...
# 6   1.000000  The score is 1.00 because the sentence in the ...
# 7   0.206897  The score is 0.21 because, although there are ...
# 8   1.000000  The score is 1.00 because the answer was fully...
# 9   1.000000  The score is 1.00 because there are no contrad...
# 10  0.571429  The score is 0.57 because the first node in th...
# 11  1.000000  The score is 1.00 because the sentence in the ...
# 12  0.036364  The score is 0.04 because, although most of th...
# 13  1.000000  The score is 1.00 because the answer was fully...
# 14  1.000000  The score is 1.00 because there are no contrad...
# 15  0.615760  The score is 0.62 because while several releva...
# 16  1.000000  The score is 1.00 because every part of the ex...
# 17  0.584615  The score is 0.58 because, while there are sev...
# 18  1.000000  The score is 1.00 because the answer was fully...
# 19  1.000000  The score is 1.00 because there are no contrad...
